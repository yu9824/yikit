# %% [markdown]
# 例用

# %%
import sys, os
sys.path.append(os.path.dirname(os.getcwd()))

# %% [markdown]
# ### モジュールのインポート

# %%
from wrapper_method import WrapperSelector
from sklearn.datasets import load_boston
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### サンプルデータの取得

# %%
boston = load_boston()
X = pd.DataFrame(boston['data'], columns = boston['feature_names'])
y = pd.Series(boston['target'], name = 'PRICE')
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# ### 削減してみる

# %%
selector = WrapperSelector(random_state = 334)
selector.fit(X, y)
X_selected = X.loc[:, selector.get_support()]
X_selected.head()
# Out:
# Calc r_ccmax: 100%|██████████| 10000/10000 [00:08<00:00, 1199.01it/s]
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	10 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	11 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	12 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	13 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	14 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	15 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	16 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	17 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	18 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	19 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	20 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	21 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	22 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	23 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	24 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	25 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	26 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	27 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	28 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	29 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	30 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	31 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	32 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	33 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	34 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	35 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	36 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	37 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	38 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	39 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	40 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	41 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	42 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	43 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	44 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	45 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	46 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	47 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	48 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	49 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	50 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	51 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	52 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	53 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	54 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	55 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	56 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	57 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	58 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	59 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	60 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	61 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	62 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	63 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	64 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	65 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	66 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	67 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	68 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	69 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	70 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	71 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	72 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	73 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	74 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	75 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	76 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	77 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	78 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	79 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	80 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	81 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	82 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	83 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	84 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	85 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	86 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	87 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	88 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	89 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	90 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	91 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	92 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	93 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	94 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	95 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	96 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	97 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	98 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	99 / 100
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	9
# Tentative: 	0
# Rejected: 	3
#       CRIM    NOX     RM   AGE     DIS    TAX  PTRATIO       B  LSTAT
# 0  0.00632  0.538  6.575  65.2  4.0900  296.0     15.3  396.90   4.98
# 1  0.02731  0.469  6.421  78.9  4.9671  242.0     17.8  396.90   9.14
# 2  0.02729  0.469  7.185  61.1  4.9671  242.0     17.8  392.83   4.03
# 3  0.03237  0.458  6.998  45.8  6.0622  222.0     18.7  394.63   2.94
# 4  0.06905  0.458  7.147  54.2  6.0622  222.0     18.7  396.90   5.33

# %%
selector.feature_selector_
# Out:
# BorutaPy(estimator=RandomForestRegressor(n_estimators=44,
#                                          random_state=<mtrand.RandomState object at 0x7fde0d3250f0>),
#          n_estimators='auto', perc=81.10620914857462,
#          random_state=<mtrand.RandomState object at 0x7fde0d3250f0>,
#          two_step=False, verbose=2)
